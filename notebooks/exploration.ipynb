# %% [markdown]
# # AI Should Cost Engine – Data Exploration
#
# This notebook is used for exploratory data analysis and prototyping related to the pharmaceutical/chemical manufacturing should-cost estimation engine.
#
# ## Purpose
#
# - Explore ROS (Recipe of Synthesis) document structures
# - Prototype cost extraction logic before integrating into the backend
# - Analyze historical cost data for benchmarking
# - Validate Azure OpenAI response formats
#
# ## Sections
#
# 1. **Document Parsing** – Test PDF/Excel/Word extraction
# 2. **Azure OpenAI** – Prototype prompt engineering
# 3. **Cost Benchmarking** – Compare AI estimates vs. actuals
# 4. **Visualization** – Cost breakdown charts
